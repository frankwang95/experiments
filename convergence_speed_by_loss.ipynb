# %%
from learning_lib.nn.ffnn import FFNN
from learning_lib.nn.monitoring.loss import LossMonitor

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

import plotly.offline as plotly
import plotly.graph_objs as go
# Out:
# /home/fwang/anaconda3/envs/experiments/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
plotly.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Data

# %%
dataset = input_data.read_data_sets("MNIST_data/", one_hot=True)

train_data = dataset.train.next_batch(1000000)
train_in = train_data[0] - train_data[0].mean()
train_labels = train_data[1]
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Theoretically, neural networks with Mean Squared Loss should be able fit a standard classification problem. However many classification models use cross-entropy loss with softmax instead. Here we investigate the hypothesis that the latter exhibits much stronger optimization properties and investigate why this might be.

# %% [markdown]
# # MSE Loss

# %%
lc = [
    784,
    {
        'n_nodes': 2048, 'activation': tf.nn.tanh, 'init_weight_lower': -1, 'init_weight_upper': 1,
        'init_bias_lower': 0, 'init_bias_upper': 1
    },
    {
        'n_nodes': 10, 'activation': tf.nn.softmax, 'init_weight_lower': -1, 'init_weight_upper': 1,
        'init_bias_lower': 0, 'init_bias_upper': 1
    }
]

# %%
monitors = [LossMonitor(100)]

# %%
network_mse_softmax = FFNN(lc, monitors=monitors)

# %%
# %%time
network_mse_softmax.train(
    train_in,
    train_labels,
    epochs=4400*10,
    batch_size=100,
    report_interval=100,
    optimizer=tf.train.GradientDescentOptimizer(0.01)
)
# Out:
# Reached epoch 35200
# Reached epoch 35300
# Reached epoch 35400
# Reached epoch 35500
# Reached epoch 35600
# Reached epoch 35700
# Reached epoch 35800
# Reached epoch 35900
# Reached epoch 36000
# Reached epoch 36100
# Reached epoch 36200
# Reached epoch 36300
# Reached epoch 36400
# Reached epoch 36500
# Reached epoch 36600
# Reached epoch 36700
# Reached epoch 36800
# Reached epoch 36900
# Reached epoch 37000
# Reached epoch 37100
# Reached epoch 37200
# Reached epoch 37300
# Reached epoch 37400
# Reached epoch 37500
# Reached epoch 37600
# Reached epoch 37700
# Reached epoch 37800
# Reached epoch 37900
# Reached epoch 38000
# Reached epoch 38100
# Reached epoch 38200
# Reached epoch 38300
# Reached epoch 38400
# Reached epoch 38500
# Reached epoch 38600
# Reached epoch 38700
# Reached epoch 38800
# Reached epoch 38900
# Reached epoch 39000
# Reached epoch 39100
# Reached epoch 39200
# Reached epoch 39300
# Reached epoch 39400
# Reached epoch 39500
# Reached epoch 39600
# Reached epoch 39700
# Reached epoch 39800
# Reached epoch 39900
# Reached epoch 40000
# Reached epoch 40100
# Reached epoch 40200
# Reached epoch 40300
# Reached epoch 40400
# Reached epoch 40500
# Reached epoch 40600
# Reached epoch 40700
# Reached epoch 40800
# Reached epoch 40900
# Reached epoch 41000
# Reached epoch 41100
# Reached epoch 41200
# Reached epoch 41300
# Reached epoch 41400
# Reached epoch 41500
# Reached epoch 41600
# Reached epoch 41700
# Reached epoch 41800
# Reached epoch 41900
# Reached epoch 42000
# Reached epoch 42100
# Reached epoch 42200
# Reached epoch 42300
# Reached epoch 42400
# Reached epoch 42500
# Reached epoch 42600
# Reached epoch 42700
# Reached epoch 42800
# Reached epoch 42900
# Reached epoch 43000
# Reached epoch 43100
# Reached epoch 43200
# Reached epoch 43300
# Reached epoch 43400
# Reached epoch 43500
# Reached epoch 43600
# Reached epoch 43700
# Reached epoch 43800
# Reached epoch 43900
# Reached epoch 44000
# Reached epoch 44100
# Reached epoch 44200
# Reached epoch 44300
# Reached epoch 44400
# Reached epoch 44500
# Reached epoch 44600
# Reached epoch 44700
# Reached epoch 44800
# Reached epoch 44900
# Reached epoch 45000
# Reached epoch 45100
# Reached epoch 45200
# Reached epoch 45300
# Reached epoch 45400
# Reached epoch 45500
# Reached epoch 45600
# Reached epoch 45700
# Reached epoch 45800
# Reached epoch 45900
# Reached epoch 46000
# Reached epoch 46100
# Reached epoch 46200
# Reached epoch 46300
# Reached epoch 46400
# Reached epoch 46500
# Reached epoch 46600
# Reached epoch 46700
# Reached epoch 46800
# Reached epoch 46900
# Reached epoch 47000
# Reached epoch 47100
# Reached epoch 47200
# Reached epoch 47300
# Reached epoch 47400
# Reached epoch 47500
# Reached epoch 47600
# Reached epoch 47700
# Reached epoch 47800
# Reached epoch 47900
# Reached epoch 48000
# Reached epoch 48100
# Reached epoch 48200
# Reached epoch 48300
# Reached epoch 48400
# Reached epoch 48500
# Reached epoch 48600
# Reached epoch 48700
# Reached epoch 48800
# Reached epoch 48900
# Reached epoch 49000
# Reached epoch 49100
# Reached epoch 49200
# Reached epoch 49300
# Reached epoch 49400
# Reached epoch 49500
# Reached epoch 49600
# Reached epoch 49700
# Reached epoch 49800
# Reached epoch 49900
# Reached epoch 50000
# Reached epoch 50100
# Reached epoch 50200
# Reached epoch 50300
# Reached epoch 50400
# Reached epoch 50500
# Reached epoch 50600
# Reached epoch 50700
# Reached epoch 50800
# Reached epoch 50900
# Reached epoch 51000
# Reached epoch 51100
# Reached epoch 51200
# Reached epoch 51300
# Reached epoch 51400
# Reached epoch 51500
# Reached epoch 51600
# Reached epoch 51700
# Reached epoch 51800
# Reached epoch 51900
# Reached epoch 52000
# Reached epoch 52100
# Reached epoch 52200
# Reached epoch 52300
# Reached epoch 52400
# Reached epoch 52500
# Reached epoch 52600
# Reached epoch 52700
# Reached epoch 52800
# Reached epoch 52900
# Reached epoch 53000
# Reached epoch 53100
# Reached epoch 53200
# Reached epoch 53300
# Reached epoch 53400
# Reached epoch 53500
# Reached epoch 53600
# Reached epoch 53700
# Reached epoch 53800
# Reached epoch 53900
# Reached epoch 54000
# Reached epoch 54100
# Reached epoch 54200
# Reached epoch 54300
# Reached epoch 54400
# Reached epoch 54500
# Reached epoch 54600
# Reached epoch 54700
# Reached epoch 54800
# Reached epoch 54900
# Reached epoch 55000
# Reached epoch 55100
# Reached epoch 55200
# Reached epoch 55300
# Reached epoch 55400
# Reached epoch 55500
# Reached epoch 55600
# Reached epoch 55700
# Reached epoch 55800
# Reached epoch 55900
# Reached epoch 56000
# Reached epoch 56100
# Reached epoch 56200
# Reached epoch 56300
# Reached epoch 56400
# Reached epoch 56500
# Reached epoch 56600
# Reached epoch 56700
# Reached epoch 56800
# Reached epoch 56900
# Reached epoch 57000
# Reached epoch 57100
# Reached epoch 57200
# Reached epoch 57300
# Reached epoch 57400
# Reached epoch 57500
# Reached epoch 57600
# Reached epoch 57700
# Reached epoch 57800
# Reached epoch 57900
# Reached epoch 58000
# Reached epoch 58100
# Reached epoch 58200
# Reached epoch 58300
# Reached epoch 58400
# Reached epoch 58500
# Reached epoch 58600
# Reached epoch 58700
# Reached epoch 58800
# Reached epoch 58900
# Reached epoch 59000
# Reached epoch 59100
# Reached epoch 59200
# Reached epoch 59300
# Reached epoch 59400
# Reached epoch 59500
# Reached epoch 59600
# Reached epoch 59700
# Reached epoch 59800
# Reached epoch 59900
# Reached epoch 60000
# Reached epoch 60100
# Reached epoch 60200
# Reached epoch 60300
# Reached epoch 60400
# Reached epoch 60500
# Reached epoch 60600
# Reached epoch 60700
# Reached epoch 60800
# Reached epoch 60900
# Reached epoch 61000
# Reached epoch 61100
# Reached epoch 61200
# Reached epoch 61300
# Reached epoch 61400
# Reached epoch 61500
# Reached epoch 61600
# Reached epoch 61700
# Reached epoch 61800
# Reached epoch 61900
# Reached epoch 62000
# Reached epoch 62100
# Reached epoch 62200
# Reached epoch 62300
# Reached epoch 62400
# Reached epoch 62500
# Reached epoch 62600
# Reached epoch 62700
# Reached epoch 62800
# Reached epoch 62900
# Reached epoch 63000
# Reached epoch 63100
# Reached epoch 63200
# Reached epoch 63300
# Reached epoch 63400
# Reached epoch 63500
# Reached epoch 63600
# Reached epoch 63700
# Reached epoch 63800
# Reached epoch 63900
# Reached epoch 64000
# Reached epoch 64100
# Reached epoch 64200
# Reached epoch 64300
# Reached epoch 64400
# Reached epoch 64500
# Reached epoch 64600
# Reached epoch 64700
# Reached epoch 64800
# Reached epoch 64900
# Reached epoch 65000
# Reached epoch 65100
# Reached epoch 65200
# Reached epoch 65300
# Reached epoch 65400
# Reached epoch 65500
# Reached epoch 65600
# Reached epoch 65700
# Reached epoch 65800
# Reached epoch 65900
# Reached epoch 66000
# Reached epoch 66100
# Reached epoch 66200
# Reached epoch 66300
# Reached epoch 66400
# Reached epoch 66500
# Reached epoch 66600
# Reached epoch 66700
# Reached epoch 66800
# Reached epoch 66900
# Reached epoch 67000
# Reached epoch 67100
# Reached epoch 67200
# Reached epoch 67300
# Reached epoch 67400
# Reached epoch 67500
# Reached epoch 67600
# Reached epoch 67700
# Reached epoch 67800
# Reached epoch 67900
# Reached epoch 68000
# Reached epoch 68100
# Reached epoch 68200
# Reached epoch 68300
# Reached epoch 68400
# Reached epoch 68500
# Reached epoch 68600
# Reached epoch 68700
# Reached epoch 68800
# Reached epoch 68900
# Reached epoch 69000
# Reached epoch 69100
# Reached epoch 69200
# Reached epoch 69300
# Reached epoch 69400
# Reached epoch 69500
# Reached epoch 69600
# Reached epoch 69700
# Reached epoch 69800
# Reached epoch 69900
# Reached epoch 70000
# Reached epoch 70100
# Reached epoch 70200
# Reached epoch 70300
# Reached epoch 70400
# Reached epoch 70500
# Reached epoch 70600
# Reached epoch 70700
# Reached epoch 70800
# Reached epoch 70900
# Reached epoch 71000
# Reached epoch 71100
# Reached epoch 71200
# Reached epoch 71300
# Reached epoch 71400
# Reached epoch 71500
# Reached epoch 71600
# Reached epoch 71700
# Reached epoch 71800
# Reached epoch 71900
# Reached epoch 72000
# Reached epoch 72100
# Reached epoch 72200
# Reached epoch 72300
# Reached epoch 72400
# Reached epoch 72500
# Reached epoch 72600
# Reached epoch 72700
# Reached epoch 72800
# Reached epoch 72900
# Reached epoch 73000
# Reached epoch 73100
# Reached epoch 73200
# Reached epoch 73300
# Reached epoch 73400
# Reached epoch 73500
# Reached epoch 73600
# Reached epoch 73700
# Reached epoch 73800
# Reached epoch 73900
# Reached epoch 74000
# Reached epoch 74100
# Reached epoch 74200
# Reached epoch 74300
# Reached epoch 74400
# Reached epoch 74500
# Reached epoch 74600
# Reached epoch 74700
# Reached epoch 74800
# Reached epoch 74900
# Reached epoch 75000
# Reached epoch 75100
# Reached epoch 75200
# Reached epoch 75300
# Reached epoch 75400
# Reached epoch 75500
# Reached epoch 75600
# Reached epoch 75700
# Reached epoch 75800
# Reached epoch 75900
# Reached epoch 76000
# Reached epoch 76100
# Reached epoch 76200
# Reached epoch 76300
# Reached epoch 76400
# Reached epoch 76500
# Reached epoch 76600
# Reached epoch 76700
# Reached epoch 76800
# Reached epoch 76900
# Reached epoch 77000
# Reached epoch 77100
# Reached epoch 77200
# Reached epoch 77300
# Reached epoch 77400
# Reached epoch 77500
# Reached epoch 77600
# Reached epoch 77700
# Reached epoch 77800
# Reached epoch 77900
# Reached epoch 78000
# Reached epoch 78100
# Reached epoch 78200
# Reached epoch 78300
# Reached epoch 78400
# Reached epoch 78500
# Reached epoch 78600
# Reached epoch 78700
# Reached epoch 78800
# Reached epoch 78900
# Reached epoch 79000
# Reached epoch 79100
# CPU times: user 1h 3min 19s, sys: 1h 21min 51s, total: 2h 25min 10s
# Wall time: 2h 11min 52s

# %% [markdown]
# # Cross Entropy Loss

# %%
def cross_entropy_with_softmax(model_output, true_output):
    return tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits_v2(labels=true_output, logits=model_output))

# %%
lc = [
    784,
    {
        'n_nodes': 2048, 'activation': tf.nn.tanh, 'init_weight_lower': -1, 'init_weight_upper': 1,
        'init_bias_lower': 0, 'init_bias_upper': 1
    },
    {
        'n_nodes': 10, 'activation': tf.identity, 'init_weight_lower': -1, 'init_weight_upper': 1,
        'init_bias_lower': 0, 'init_bias_upper': 1
    }
]

# %%
monitors = [LossMonitor(100)]

# %%
network_xe = FFNN(lc, post_proc_function=tf.nn.softmax, loss_func=cross_entropy_with_softmax, monitors=monitors)

# %%
# %%time
print("Test")
network_xe.train(
    train_in,
    train_labels,
    epochs=4400,
    batch_size=100,
    optimizer=tf.train.GradientDescentOptimizer(0.01)
)
# Out:
# Test
# Reached epoch 4399
# CPU times: user 2min 38s, sys: 6min 51s, total: 9min 29s
# Wall time: 9min 6s

# %% [markdown]
# # Comparison

# %%
train_pred = network_xe.evaluate(train_in)
np.sum(train_pred.argmax(axis=1) == train_labels.argmax(axis=1)) / train_in.shape[0]
# Out:
# 0.9982181818181818

# %%
plotly.iplot([
    go.Scatter(
        x=network_xe.monitors[0].values['epochs'],
        y=network_xe.monitors[0].values['loss']
    )
])
# Out:
# <div id="a770ebcd-0739-4593-b285-e16ea93f79e8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a770ebcd-0739-4593-b285-e16ea93f79e8", [{"type": "scatter", "x": [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 900.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 2100.0, 2200.0, 2300.0, 2400.0, 2500.0, 2600.0, 2700.0, 2800.0, 2900.0, 3000.0, 3100.0, 3200.0, 3300.0, 3400.0, 3500.0, 3600.0, 3700.0, 3800.0, 3900.0, 4000.0, 4100.0, 4200.0, 4300.0], "y": [5148697.0, 329628.03125, 222404.21875, 258018.5, 140519.59375, 94354.7421875, 96137.609375, 70627.1328125, 82703.890625, 40957.859375, 66254.046875, 33195.20703125, 18859.025390625, 45753.66796875, 22118.98828125, 39221.94140625, 12655.3994140625, 10904.662109375, 13553.28125, 16239.986328125, 11634.359375, 8939.890625, 5090.2294921875, 5445.4775390625, 4858.470703125, 5386.62890625, 3186.485107421875, 4638.763671875, 5973.62890625, 8020.6728515625, 3579.8662109375, 2444.99951171875, 2460.64697265625, 5659.8935546875, 2190.3681640625, 3629.98974609375, 1484.8687744140625, 1075.138427734375, 1070.483154296875, 831.1375732421875, 928.9796142578125, 3359.83349609375, 1756.793212890625, 1557.668701171875]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
train_pred = network_mse_softmax.evaluate(train_in)
np.sum(train_pred.argmax(axis=1) == train_labels.argmax(axis=1)) / train_in.shape[0]
# Out:
# 0.5658181818181818

# %%
plotly.iplot([
    go.Scatter(
        x=pd.DataFrame(network_mse_softmax.learning_curve)[0],
        y=pd.DataFrame(network_mse_softmax.learning_curve)[1]
    )
])
# Out:
# <div id="6b9f4940-d797-4ce9-b9e2-3ba274ab839a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6b9f4940-d797-4ce9-b9e2-3ba274ab839a", [{"type": "scatter", "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900, 12000, 12100, 12200, 12300, 12400, 12500, 12600, 12700, 12800, 12900, 13000, 13100, 13200, 13300, 13400, 13500, 13600, 13700, 13800, 13900, 14000, 14100, 14200, 14300, 14400, 14500, 14600, 14700, 14800, 14900, 15000, 15100, 15200, 15300, 15400, 15500, 15600, 15700, 15800, 15900, 16000, 16100, 16200, 16300, 16400, 16500, 16600, 16700, 16800, 16900, 17000, 17100, 17200, 17300, 17400, 17500, 17600, 17700, 17800, 17900, 18000, 18100, 18200, 18300, 18400, 18500, 18600, 18700, 18800, 18900, 19000, 19100, 19200, 19300, 19400, 19500, 19600, 19700, 19800, 19900, 20000, 20100, 20200, 20300, 20400, 20500, 20600, 20700, 20800, 20900, 21000, 21100, 21200, 21300, 21400, 21500, 21600, 21700, 21800, 21900, 22000, 22100, 22200, 22300, 22400, 22500, 22600, 22700, 22800, 22900, 23000, 23100, 23200, 23300, 23400, 23500, 23600, 23700, 23800, 23900, 24000, 24100, 24200, 24300, 24400, 24500, 24600, 24700, 24800, 24900, 25000, 25100, 25200, 25300, 25400, 25500, 25600, 25700, 25800, 25900, 26000, 26100, 26200, 26300, 26400, 26500, 26600, 26700, 26800, 26900, 27000, 27100, 27200, 27300, 27400, 27500, 27600, 27700, 27800, 27900, 28000, 28100, 28200, 28300, 28400, 28500, 28600, 28700, 28800, 28900, 29000, 29100, 29200, 29300, 29400, 29500, 29600, 29700, 29800, 29900, 30000, 30100, 30200, 30300, 30400, 30500, 30600, 30700, 30800, 30900, 31000, 31100, 31200, 31300, 31400, 31500, 31600, 31700, 31800, 31900, 32000, 32100, 32200, 32300, 32400, 32500, 32600, 32700, 32800, 32900, 33000, 33100, 33200, 33300, 33400, 33500, 33600, 33700, 33800, 33900, 34000, 34100, 34200, 34300, 34400, 34500, 34600, 34700, 34800, 34900, 35000, 35100, 35200, 35300, 35400, 35500, 35600, 35700, 35800, 35900, 36000, 36100, 36200, 36300, 36400, 36500, 36600, 36700, 36800, 36900, 37000, 37100, 37200, 37300, 37400, 37500, 37600, 37700, 37800, 37900, 38000, 38100, 38200, 38300, 38400, 38500, 38600, 38700, 38800, 38900, 39000, 39100, 39200, 39300, 39400, 39500, 39600, 39700, 39800, 39900, 40000, 40100, 40200, 40300, 40400, 40500, 40600, 40700, 40800, 40900, 41000, 41100, 41200, 41300, 41400, 41500, 41600, 41700, 41800, 41900, 42000, 42100, 42200, 42300, 42400, 42500, 42600, 42700, 42800, 42900, 43000, 43100, 43200, 43300, 43400, 43500, 43600, 43700, 43800, 43900, 44000, 44100, 44200, 44300, 44400, 44500, 44600, 44700, 44800, 44900, 45000, 45100, 45200, 45300, 45400, 45500, 45600, 45700, 45800, 45900, 46000, 46100, 46200, 46300, 46400, 46500, 46600, 46700, 46800, 46900, 47000, 47100, 47200, 47300, 47400, 47500, 47600, 47700, 47800, 47900, 48000, 48100, 48200, 48300, 48400, 48500, 48600, 48700, 48800, 48900, 49000, 49100, 49200, 49300, 49400, 49500, 49600, 49700, 49800, 49900, 50000, 50100, 50200, 50300, 50400, 50500, 50600, 50700, 50800, 50900, 51000, 51100, 51200, 51300, 51400, 51500, 51600, 51700, 51800, 51900, 52000, 52100, 52200, 52300, 52400, 52500, 52600, 52700, 52800, 52900, 53000, 53100, 53200, 53300, 53400, 53500, 53600, 537 ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# These two examples show that all else being equal, having a softmax + cross entopy loss converges at a much faster rate than just MSE. Both methods appear to exhibit strong fitment to the data given sufficient time but convergence of the MSE loss was significantly slower than cross-entropy.
