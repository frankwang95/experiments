# %%
from lib_learning.nn.ffnn import FFNN
from lib_learning.nn_monitoring.loss import LossMonitor

import gzip
import pandas as pd
import numpy as np
import tensorflow as tf

import plotly.offline as plotly
import plotly.graph_objs as go

# %%
plotly.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data

# %%
with gzip.open('../data/MNIST_data/test_inputs.gz', 'rb') as f:
    test_in = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1,28*28) / 255.0
with gzip.open('../data/MNIST_data/train_inputs.gz', 'rb') as f:
    train_in = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1,28*28) / 255.0
with gzip.open('../data/MNIST_data/test_targets.gz', 'rb') as f:
    test_labels_raw = np.frombuffer(f.read(), np.uint8, offset=8)
with gzip.open('../data/MNIST_data/train_targets.gz', 'rb') as f:
    train_labels_raw = np.frombuffer(f.read(), np.uint8, offset=8)
    
test_labels = np.zeros((test_labels_raw.shape[0], 10))
test_labels[np.arange(test_labels_raw.shape[0]), test_labels_raw] = 1
train_labels = np.zeros((train_labels_raw.shape[0], 10))
train_labels[np.arange(train_labels_raw.shape[0]), train_labels_raw] = 1

test_in = test_in.astype('float32')
train_in = train_in.astype('float32')
test_lables = test_labels.astype('float32')
train_lables = train_labels.astype('float32')

# %%
# Run this if you want to normalize to zero mean
test_in = test_in - train_in.mean()
train_in = train_in - train_in.mean()

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Theoretically, neural networks with Mean Squared Loss should be able fit a standard classification problem. However many classification models use cross-entropy loss with softmax instead. Here we investigate the hypothesis that the latter exhibits much stronger optimization properties and investigate why this might be.

# %% [markdown]
# # MSE Loss

# %%
lc = [
    784,
    {
        'n_nodes': 2048, 'activation': tf.nn.tanh, 'init_weight_mean': 0, 'init_weight_stddev': 0.01,
        'init_bias_mean': 0, 'init_bias_stddev': 0.01
    },
    {
        'n_nodes': 10, 'activation': tf.nn.softmax, 'init_weight_mean': 0, 'init_weight_stddev': 0.01,
        'init_bias_mean': 0, 'init_bias_stddev': 0.01
    }
]

# %%
monitors = [LossMonitor(100)]

# %%
network_mse_softmax = FFNN(lc, monitors=monitors)
# Out:
# WARNING:tensorflow:From /home/fkwang/anaconda3/envs/experiments_archive/lib/python3.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# %%time
network_mse_softmax.init_session()
network_mse_softmax.train_offline(
    train_in,
    train_labels,
    epochs=440 * 100,
    batch_size=100
)
# Out:
# WARNING:tensorflow:From /home/fkwang/anaconda3/envs/experiments_archive/lib/python3.7/site-packages/lib_learning/nn/nn_base_class.py:169: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/fkwang/anaconda3/envs/experiments_archive/lib/python3.7/site-packages/lib_learning/nn/nn_base_class.py:170: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Epoch: 44000
# CPU times: user 1h 24min 41s, sys: 26min 3s, total: 1h 50min 45s
# Wall time: 46min 38s

# %% [markdown]
# # Cross Entropy Loss

# %%
def cross_entropy_with_softmax(model_output, true_output):
    return tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits_v2(labels=true_output, logits=model_output))

# %%
lc = [
    784,
    {
        'n_nodes': 2048, 'activation': tf.nn.tanh, 'init_weight_mean': 0, 'init_weight_stddev': 0.01,
        'init_bias_mean': 0, 'init_bias_stddev': 0.01
    },
    {
        'n_nodes': 10, 'activation': tf.nn.softmax, 'init_weight_mean': 0, 'init_weight_stddev': 0.01,
        'init_bias_mean': 0, 'init_bias_stddev': 0.01
    }
]

# %%
monitors = [LossMonitor(100)]

# %%
# %%time
network_xe = FFNN(lc, post_proc_function=tf.nn.softmax, loss_func=cross_entropy_with_softmax, monitors=monitors)
network_xe.init_session()
network_xe.train_offline(
    train_in,
    train_labels,
    epochs=440 * 100,
    batch_size=100,
)
# Out:
# Epoch: 44000
# CPU times: user 1h 24min 46s, sys: 26min 49s, total: 1h 51min 35s
# Wall time: 48min 13s

# %% [markdown]
# # Comparison

# %%
train_pred = network_xe.predict(train_in)
np.sum(train_pred.argmax(axis=1) == train_labels.argmax(axis=1)) / train_in.shape[0]
# Out:
# 0.98085

# %%
train_pred = network_mse_softmax.predict(train_in)
np.sum(train_pred.argmax(axis=1) == train_labels.argmax(axis=1)) / train_in.shape[0]
# Out:
# 0.9299

# %%
plotly.iplot([
    go.Scatter(
        x=network_xe.monitors[0].values['epochs'],
        y=network_xe.monitors[0].values['loss']
    )
])
# Out:
# <div>
#
#
#             <div id="bbaa7915-b230-4ecb-95d7-b45661860851" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bbaa7915-b230-4ecb-95d7-b45661860851")) {
#                     Plotly.newPlot(
#                         'bbaa7915-b230-4ecb-95d7-b45661860851',
#                         [{"type": "scatter", "x": [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 900.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 2100.0, 2200.0, 2300.0, 2400.0, 2500.0, 2600.0, 2700.0, 2800.0, 2900.0, 3000.0, 3100.0, 3200.0, 3300.0, 3400.0, 3500.0, 3600.0, 3700.0, 3800.0, 3900.0, 4000.0, 4100.0, 4200.0, 4300.0, 4400.0, 4500.0, 4600.0, 4700.0, 4800.0, 4900.0, 5000.0, 5100.0, 5200.0, 5300.0, 5400.0, 5500.0, 5600.0, 5700.0, 5800.0, 5900.0, 6000.0, 6100.0, 6200.0, 6300.0, 6400.0, 6500.0, 6600.0, 6700.0, 6800.0, 6900.0, 7000.0, 7100.0, 7200.0, 7300.0, 7400.0, 7500.0, 7600.0, 7700.0, 7800.0, 7900.0, 8000.0, 8100.0, 8200.0, 8300.0, 8400.0, 8500.0, 8600.0, 8700.0, 8800.0, 8900.0, 9000.0, 9100.0, 9200.0, 9300.0, 9400.0, 9500.0, 9600.0, 9700.0, 9800.0, 9900.0, 10000.0, 10100.0, 10200.0, 10300.0, 10400.0, 10500.0, 10600.0, 10700.0, 10800.0, 10900.0, 11000.0, 11100.0, 11200.0, 11300.0, 11400.0, 11500.0, 11600.0, 11700.0, 11800.0, 11900.0, 12000.0, 12100.0, 12200.0, 12300.0, 12400.0, 12500.0, 12600.0, 12700.0, 12800.0, 12900.0, 13000.0, 13100.0, 13200.0, 13300.0, 13400.0, 13500.0, 13600.0, 13700.0, 13800.0, 13900.0, 14000.0, 14100.0, 14200.0, 14300.0, 14400.0, 14500.0, 14600.0, 14700.0, 14800.0, 14900.0, 15000.0, 15100.0, 15200.0, 15300.0, 15400.0, 15500.0, 15600.0, 15700.0, 15800.0, 15900.0, 16000.0, 16100.0, 16200.0, 16300.0, 16400.0, 16500.0, 16600.0, 16700.0, 16800.0, 16900.0, 17000.0, 17100.0, 17200.0, 17300.0, 17400.0, 17500.0, 17600.0, 17700.0, 17800.0, 17900.0, 18000.0, 18100.0, 18200.0, 18300.0, 18400.0, 18500.0, 18600.0, 18700.0, 18800.0, 18900.0, 19000.0, 19100.0, 19200.0, 19300.0, 19400.0, 19500.0, 19600.0, 19700.0, 19800.0, 19900.0, 20000.0, 20100.0, 20200.0, 20300.0, 20400.0, 20500.0, 20600.0, 20700.0, 20800.0, 20900.0, 21000.0, 21100.0, 21200.0, 21300.0, 21400.0, 21500.0, 21600.0, 21700.0, 21800.0, 21900.0, 22000.0, 22100.0, 22200.0, 22300.0, 22400.0, 22500.0, 22600.0, 22700.0, 22800.0, 22900.0, 23000.0, 23100.0, 23200.0, 23300.0, 23400.0, 23500.0, 23600.0, 23700.0, 23800.0, 23900.0, 24000.0, 24100.0, 24200.0, 24300.0, 24400.0, 24500.0, 24600.0, 24700.0, 24800.0, 24900.0, 25000.0, 25100.0, 25200.0, 25300.0, 25400.0, 25500.0, 25600.0, 25700.0, 25800.0, 25900.0, 26000.0, 26100.0, 26200.0, 26300.0, 26400.0, 26500.0, 26600.0, 26700.0, 26800.0, 26900.0, 27000.0, 27100.0, 27200.0, 27300.0, 27400.0, 27500.0, 27600.0, 27700.0, 27800.0, 27900.0, 28000.0, 28100.0, 28200.0, 28300.0, 28400.0, 28500.0, 28600.0, 28700.0, 28800.0, 28900.0, 29000.0, 29100.0, 29200.0, 29300.0, 29400.0, 29500.0, 29600.0, 29700.0, 29800.0, 29900.0, 30000.0, 30100.0, 30200.0, 30300.0, 30400.0, 30500.0, 30600.0, 30700.0, 30800.0, 30900.0, 31000.0, 31100.0, 31200.0, 31300.0, 31400.0, 31500.0, 31600.0, 31700.0, 31800.0, 31900.0, 32000.0, 32100.0, 32200.0, 32300.0, 32400.0, 32500.0, 32600.0, 32700.0, 32800.0, 32900.0, 33000.0, 33100.0, 33200.0, 33300.0, 33400.0, 33500.0, 33600.0, 33700.0, 33800.0, 33900.0, 34000.0, 34100.0, 34200.0, 34300.0, 34400.0, 34500.0, 34600.0, 34700.0, 34800.0, 34900.0, 35000.0, 35100.0, 35200.0, 35300.0, 35400.0, 35500.0, 35600.0, 35700.0, 35800.0, 35900.0, 36000.0, 36100.0, 36200.0, 36300.0, 36400.0, 36500.0, 36600.0, 36700.0, 36800.0, 36900.0, 37000.0, 37100.0, 37200.0, 37300.0, 37400.0, 37500.0, 37600.0, 37700.0, 37800.0, 37900.0, 38000.0, 38100.0, 38200.0, 38300.0, 38400.0, 38500.0, 38600.0, 38700.0, 38800.0, 38900.0, 39000.0, 39100.0, 39200.0, 39300.0, 39400.0, 39500.0, 39600.0, 39700.0, 39800.0, 39900.0, 40000.0, 40100.0, 40200.0, 40300.0, 40400.0, 40500.0, 40600.0, 40700.0, 40800.0, 40900.0, 41000.0, 41100.0, 41200.0, 41300.0, 41400.0, 41500.0, 41600.0, 41700.0, 41800.0, 41900.0, 42000.0, 42100.0, 42200.0, 42300.0, 42400.0, 42500.0, 42600.0, 42700.0, 42800.0, 42900.0, 43000.0, 43100.0, 43200.0, 43300.0, 43400.0, 43500.0, 43600.0, 43700.0, 43800.0, 43900.0], "y": [218.07643127441406, 169.19662475585938, 172.91598510742188, 164.025146484375, 159.988327026367 ...

# %%
plotly.iplot([
#     go.Scatter(
#         x=network_xe.monitors[0].values['epochs'],
#         y=network_xe.monitors[0].values['loss']
#     ),
    go.Scatter(
        x=network_mse_softmax.monitors[0].values['epochs'],
        y=network_mse_softmax.monitors[0].values['loss']
    )
])
# Out:
# <div>
#
#
#             <div id="0957724a-58eb-4da0-90d2-3a63c1e87d03" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0957724a-58eb-4da0-90d2-3a63c1e87d03")) {
#                     Plotly.newPlot(
#                         '0957724a-58eb-4da0-90d2-3a63c1e87d03',
#                         [{"type": "scatter", "x": [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 900.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 2100.0, 2200.0, 2300.0, 2400.0, 2500.0, 2600.0, 2700.0, 2800.0, 2900.0, 3000.0, 3100.0, 3200.0, 3300.0, 3400.0, 3500.0, 3600.0, 3700.0, 3800.0, 3900.0, 4000.0, 4100.0, 4200.0, 4300.0, 4400.0, 4500.0, 4600.0, 4700.0, 4800.0, 4900.0, 5000.0, 5100.0, 5200.0, 5300.0, 5400.0, 5500.0, 5600.0, 5700.0, 5800.0, 5900.0, 6000.0, 6100.0, 6200.0, 6300.0, 6400.0, 6500.0, 6600.0, 6700.0, 6800.0, 6900.0, 7000.0, 7100.0, 7200.0, 7300.0, 7400.0, 7500.0, 7600.0, 7700.0, 7800.0, 7900.0, 8000.0, 8100.0, 8200.0, 8300.0, 8400.0, 8500.0, 8600.0, 8700.0, 8800.0, 8900.0, 9000.0, 9100.0, 9200.0, 9300.0, 9400.0, 9500.0, 9600.0, 9700.0, 9800.0, 9900.0, 10000.0, 10100.0, 10200.0, 10300.0, 10400.0, 10500.0, 10600.0, 10700.0, 10800.0, 10900.0, 11000.0, 11100.0, 11200.0, 11300.0, 11400.0, 11500.0, 11600.0, 11700.0, 11800.0, 11900.0, 12000.0, 12100.0, 12200.0, 12300.0, 12400.0, 12500.0, 12600.0, 12700.0, 12800.0, 12900.0, 13000.0, 13100.0, 13200.0, 13300.0, 13400.0, 13500.0, 13600.0, 13700.0, 13800.0, 13900.0, 14000.0, 14100.0, 14200.0, 14300.0, 14400.0, 14500.0, 14600.0, 14700.0, 14800.0, 14900.0, 15000.0, 15100.0, 15200.0, 15300.0, 15400.0, 15500.0, 15600.0, 15700.0, 15800.0, 15900.0, 16000.0, 16100.0, 16200.0, 16300.0, 16400.0, 16500.0, 16600.0, 16700.0, 16800.0, 16900.0, 17000.0, 17100.0, 17200.0, 17300.0, 17400.0, 17500.0, 17600.0, 17700.0, 17800.0, 17900.0, 18000.0, 18100.0, 18200.0, 18300.0, 18400.0, 18500.0, 18600.0, 18700.0, 18800.0, 18900.0, 19000.0, 19100.0, 19200.0, 19300.0, 19400.0, 19500.0, 19600.0, 19700.0, 19800.0, 19900.0, 20000.0, 20100.0, 20200.0, 20300.0, 20400.0, 20500.0, 20600.0, 20700.0, 20800.0, 20900.0, 21000.0, 21100.0, 21200.0, 21300.0, 21400.0, 21500.0, 21600.0, 21700.0, 21800.0, 21900.0, 22000.0, 22100.0, 22200.0, 22300.0, 22400.0, 22500.0, 22600.0, 22700.0, 22800.0, 22900.0, 23000.0, 23100.0, 23200.0, 23300.0, 23400.0, 23500.0, 23600.0, 23700.0, 23800.0, 23900.0, 24000.0, 24100.0, 24200.0, 24300.0, 24400.0, 24500.0, 24600.0, 24700.0, 24800.0, 24900.0, 25000.0, 25100.0, 25200.0, 25300.0, 25400.0, 25500.0, 25600.0, 25700.0, 25800.0, 25900.0, 26000.0, 26100.0, 26200.0, 26300.0, 26400.0, 26500.0, 26600.0, 26700.0, 26800.0, 26900.0, 27000.0, 27100.0, 27200.0, 27300.0, 27400.0, 27500.0, 27600.0, 27700.0, 27800.0, 27900.0, 28000.0, 28100.0, 28200.0, 28300.0, 28400.0, 28500.0, 28600.0, 28700.0, 28800.0, 28900.0, 29000.0, 29100.0, 29200.0, 29300.0, 29400.0, 29500.0, 29600.0, 29700.0, 29800.0, 29900.0, 30000.0, 30100.0, 30200.0, 30300.0, 30400.0, 30500.0, 30600.0, 30700.0, 30800.0, 30900.0, 31000.0, 31100.0, 31200.0, 31300.0, 31400.0, 31500.0, 31600.0, 31700.0, 31800.0, 31900.0, 32000.0, 32100.0, 32200.0, 32300.0, 32400.0, 32500.0, 32600.0, 32700.0, 32800.0, 32900.0, 33000.0, 33100.0, 33200.0, 33300.0, 33400.0, 33500.0, 33600.0, 33700.0, 33800.0, 33900.0, 34000.0, 34100.0, 34200.0, 34300.0, 34400.0, 34500.0, 34600.0, 34700.0, 34800.0, 34900.0, 35000.0, 35100.0, 35200.0, 35300.0, 35400.0, 35500.0, 35600.0, 35700.0, 35800.0, 35900.0, 36000.0, 36100.0, 36200.0, 36300.0, 36400.0, 36500.0, 36600.0, 36700.0, 36800.0, 36900.0, 37000.0, 37100.0, 37200.0, 37300.0, 37400.0, 37500.0, 37600.0, 37700.0, 37800.0, 37900.0, 38000.0, 38100.0, 38200.0, 38300.0, 38400.0, 38500.0, 38600.0, 38700.0, 38800.0, 38900.0, 39000.0, 39100.0, 39200.0, 39300.0, 39400.0, 39500.0, 39600.0, 39700.0, 39800.0, 39900.0, 40000.0, 40100.0, 40200.0, 40300.0, 40400.0, 40500.0, 40600.0, 40700.0, 40800.0, 40900.0, 41000.0, 41100.0, 41200.0, 41300.0, 41400.0, 41500.0, 41600.0, 41700.0, 41800.0, 41900.0, 42000.0, 42100.0, 42200.0, 42300.0, 42400.0, 42500.0, 42600.0, 42700.0, 42800.0, 42900.0, 43000.0, 43100.0, 43200.0, 43300.0, 43400.0, 43500.0, 43600.0, 43700.0, 43800.0, 43900.0], "y": [0.08982899785041809, 0.08790142834186554, 0.08638795465230942, 0.08335738629102707, 0.07735325 ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# These two examples show that all else being equal, having a softmax + cross entopy loss converges at a much faster rate than just MSE. Both methods appear to exhibit strong fitment to the data given sufficient time but convergence of the MSE loss was significantly slower than cross-entropy.
